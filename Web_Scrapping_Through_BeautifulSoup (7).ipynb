# %%
#ANS:- 1

# !pip install bs4
# !pip install requests

# %%
#importing the required libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Function to fetch header tags from a URL
def get_header_tags(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    header_tags = [header.text.strip() 
                   
for header in soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'])]
    return header_tags

# %%
# Wikipedia homepage URL
wiki_url = 'https://en.wikipedia.org/wiki/Main_Page'

# Get header tags
header_tags = get_header_tags(wiki_url)

# %%
# Create a DataFrame
df = pd.DataFrame({'Header Tags': header_tags})
print(df)
# Out:
#                       Header Tags
# 0                       Main Page
# 1            Welcome to Wikipedia
# 2   From today's featured article
# 3                Did you know ...
# 4                     In the news
# 5                     On this day
# 6      From today's featured list
# 7        Today's featured picture
# 8        Other areas of Wikipedia
# 9     Wikipedia's sister projects
# 10            Wikipedia languages

# %%
#ANS:- 2

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Function to fetch data from the given URL
def get_presidents_data(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extracting data using BeautifulSoup
    presidents_data = []
    for row in soup.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        name = columns[0].text.strip()
        term_of_office = columns[1].text.strip()
        presidents_data.append({'Name': name, 'Term of Office': term_of_office})
    
    return presidents_data

# URL of the webpage containing information about former presidents of India
presidents_url = 'https://presidentofindia.nic.in/former-presidents.htm'

# Get data about former presidents
presidents_data = get_presidents_data(presidents_url)

# Create a DataFrame
df = pd.DataFrame(presidents_data)

# Display the DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#ANS:4

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/><link href="/manifest.json" rel="manifest"/><style type="text/css">
#             @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
def scrape_odi_women_teams(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    teams_data = []
    for row in soup.find_all('tr', class_='table-body')[:10]:
        columns = row.find_all('td')
        team_name = columns[1].text.strip()
        matches = columns[2].text.strip()
        points = columns[3].text.strip()
        rating = columns[5].text.strip()  # Rating is in a different column for women's teams
        teams_data.append({'Team': team_name, 'Matches': matches, 'Points': points, 'Rating': rating})

    return teams_data

# %%
# URL for Women's ODI Team Rankings
odi_women_teams_url = 'https://www.icc-cricket.com/rankings/womens/team-rankings/odi'


# Get data for top 10 Women's ODI teams
odi_women_teams_data = scrape_odi_women_teams(odi_women_teams_url)

# Create a DataFrame
odi_women_teams_df = pd.DataFrame(odi_women_teams_data)

# Display the DataFrame
print("Top 10 Women's ODI Teams:")
print(odi_women_teams_df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 6
#       2 odi_women_teams_url = 'https://www.icc-cricket.com/rankings/womens/team-rankings/odi'
#       5 # Get data for top 10 Women's ODI teams
# ----> 6 odi_women_teams_data = scrape_odi_women_teams(odi_women_teams_url)
#       8 # Create a DataFrame
#       9 odi_women_teams_df = pd.DataFrame(odi_women_teams_data)
#
# Cell In[57], line 11, in scrape_odi_women_teams(url)
#       9     matches = columns[2].text.strip()
#      10     points = columns[3].text.strip()
# ---> 11     rating = columns[5].text.strip()  # Rating is in a different column for women's teams
#      12     teams_data.append({'Team': team_name, 'Matches': matches, 'Points': points, 'Rating': rating})
#      14 return teams_data
#
# IndexError: list index out of range

# %%
#ANS:3

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def scrape_odi_teams():
    url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    teams_data = []

    teams_table = soup.find('table', {'class': 'table'})
    rows = teams_table.find('tbody').find_all('tr')[:10]

    for row in rows:
        columns = row.find_all('td')
        team = columns[1].text.strip()
        matches = columns[2].text
        points = columns[3].text
        rating = columns[4].text.strip()

        teams_data.append({'Team': team, 'Matches': matches, 'Points': points, 'Rating': rating})

    return pd.DataFrame(teams_data)

# %%
def scrape_odi_batsmen():
    url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    batsmen_data = []

    batsmen_table = soup.find('table', {'class': 'table'})
    rows = batsmen_table.find('tbody').find_all('tr')[:10]

    for row in rows:
        columns = row.find_all('td')
        player = columns[1].text.strip()
        team = columns[2].text.strip()
        rating = columns[3].text.strip()

        batsmen_data.append({'Player': player, 'Team': team, 'Rating': rating})

    return pd.DataFrame(batsmen_data)

# %%
def scrape_odi_bowlers():
    url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    bowlers_data = []

    bowlers_table = soup.find('table', {'class': 'table'})
    rows = bowlers_table.find('tbody').find_all('tr')[:10]

    for row in rows:
        columns = row.find_all('td')
        player = columns[1].text.strip()
        team = columns[2].text.strip()
        rating = columns[3].text.strip()

        bowlers_data.append({'Player': player, 'Team': team, 'Rating': rating})

    return pd.DataFrame(bowlers_data)

# %%
if __name__ == "__main__":
    
    # a) Top 10 ODI teams
    odi_teams_df = scrape_odi_teams()
    print("Top 10 ODI Teams:")
    print(odi_teams_df)
    print()

    # b) Top 10 ODI Batsmen
    odi_batsmen_df = scrape_odi_batsmen()
    print("Top 10 ODI Batsmen:")
    print(odi_batsmen_df)
    print()

    # c) Top 10 ODI Bowlers
    odi_bowlers_df = scrape_odi_bowlers()
    print("Top 10 ODI Bowlers:")
    print(odi_bowlers_df)

# %%
#ANS:5

# %%
#Importing required liberaries
from bs4 import BeautifulSoup
import requests

# %%
page =requests.get("https://www.cnbc.com/world/?region=world")
page

# %%
soup=BeautifulSoup(page.content)
soup

# %%
headline = soup.find('div',)

# %%
#ANS:6

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles"
response = requests.get(url)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

# %%
    paper_titles = []
    authors_list = []
    published_dates = []
    paper_urls = []

    
    articles = soup.find_all("div", class_="pod-listing-header")
    for article in articles:
        
        # Extracting paper title
        title = article.find("a", class_="pod-listing-header__link").text.strip()
        paper_titles.append(title)

        # Extracting authors
        authors = article.find("div", class_="pod-listing-header__authors").text.strip()
        authors_list.append(authors)

        # Extracting published date
        date = article.find("div", class_="pod-listing-header__date").text.strip()
        published_dates.append(date)

        # Extracting paper URL
        paper_url = article.find("a", class_="pod-listing-header__link")["href"]
        paper_urls.append(paper_url)

    # Creating a DataFrame
    data = {
        'Paper Title': paper_titles,
        'Authors': authors_list,
        'Published Date': published_dates,
        'Paper URL': paper_urls
    }

    df = pd.DataFrame(data)
    print(df)

# %%
#ANS:7

# %%
#import the required libraries
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://www.dineout.co.in/delhi-restaurants")
page

# %%
soup =BeautifulSoup(page.content)
soup

# %%
#Scrapping resturant name
resturant_name = soup.find('div',class_="restnt-info cursor")
resturant_name

# %%
resturant_name.text

# %%
# Scrapping Cuisine
cuisine = soup.find('span',class_="double-line-ellipsis")
cuisine.text.replace('₹ 2,000 for 2 (approx)', '')

# %%
#scrapping loctaion'
loc=soup.find('div',class_="restnt-loc ellipsis")
loc

# %%
#scrapping Rating
rating =soup.find('div',class_="restnt-rating rating-4")
rating

# %%
#NOW we will extract the text from these tags one by one by using looping_resturant_name

restaurant_data = []

for i in soup.find_all('div', class_="restnt-info cursor"):
    restaurant_data.append(i.text.strip())

print(restaurant_data)

# %%
#NOW we will extract the text from these tags one by one by using looping


cuisine_data = []

for i in soup.find_all('div', class_="restnt-info cursor"):
    cuisine_data.append(i.text.strip())

print(cuisine_data)

# %%
#NOW we will extract the text from these tags one by one by using looping_location


loc_data = []

for i in soup.find_all('div', class_="restnt-info cursor"):
    loc_data.append(i.text.strip())

print(loc_data)

# %%
#NOW we will extract the text from these tags one by one by using looping_rating


rating_data = []

for i in soup.find_all('div', class_="restnt-info cursor"):
    rating_data.append(i.text.strip())

print(rating_data)

# %%
images = []

for i in soup.find_all('img', class_="no-img"):
    images.append(i['data-src'])

print(images)

# %%
#Making_dataframe

import pandas as pd
df=pd.DataFrame({'titles':restaurant_data,'location':loc_data,'cuisine':cuisine_data,'rating':rating_data,'image_url':images})

print(df)
